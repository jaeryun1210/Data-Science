# %% [markdown]
# # Assignment 03
# ## 학번 : 2021305082
# ## 성명 : 최재륜
# ### 제출일 : 2026.03.30

# %% [markdown]
# ## 1. 교재 p.209~p.210에 있는 연습 문제의 각 문제를 Markdown으로 나타내고 그 답을 작성하여 Jupyter Notebook 파일로 제출.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("food_consumption.csv")
df
# Out:
#          country             food_category  consumption  co2_emmission
# 0      Argentina                      Pork        10.51          37.20
# 1      Argentina                   Poultry        38.66          41.53
# 2      Argentina                      Beef        55.48        1712.00
# 3      Argentina               Lamb & Goat         1.56          54.63
# 4      Argentina                      Fish         4.36           6.96
# ...          ...                       ...          ...            ...
# 1425  Bangladesh        Milk - inc. cheese        21.91          31.21
# 1426  Bangladesh  Wheat and Wheat Products        17.47           3.33
# 1427  Bangladesh                      Rice       171.73         219.76
# 1428  Bangladesh                  Soybeans         0.61           0.27
# 1429  Bangladesh   Nuts inc. Peanut Butter         0.72           1.27
#
# [1430 rows x 4 columns]

# %% [markdown]
# ### seaborn 라이브러리에 포함된 tips 데이터셋은 레스토랑 이용 고객의 관련 데이터를 저장하고 있다. 다음 코드를 실행한 후, 아래에 이어지는 문제를 해결하시오.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. tips 데이터셋을 불러와 df에 저장한 후, day 컬럼의 값을 day에 저장하시오. day는 고객의 레스토랑 방문 요일 데이터다.

# %%
df = sns.load_dataset('tips')
day = df['day']

# %% [markdown]
# ### 2. day의 내용과 자료형(type)을 확인하시오.

# %%
display(day)
display(type(day))
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']
# pandas.core.series.Series

# %% [markdown]
# ### 3. day에 포함된 값들에 대해 도수 분포를 계산하여 fd에 저장하시오.

# %%
fd = day.value_counts()

fd
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# ### 4. fd를 이용하여 요일별 방문자 수 비율을 출력하시오.

# %%
(fd / fd.sum()) * 100
# Out:
# day
# Sat     35.655738
# Sun     31.147541
# Thur    25.409836
# Fri      7.786885
# Name: count, dtype: float64

# %% [markdown]
# ### 5. fd를 이용하여 요일별 방문자 수를 세로 방향 막대그래프로 나타내시오.

# %%
fd.plot(kind='bar')
plt.show()

# %% [markdown]
# ### 6. fd를 이용하여 요일별 방문자 수를 가로 방향 막대그래프로 나타내시오. 단, 막대의 색은 빨간색으로 하시오.

# %%
fd.plot(kind='barh', color='red')
plt.show()

# %% [markdown]
# ### 7. fd를 이용하여 요일별 방문자 수를 원그래프로 나타내시오.

# %%
fd.plot(kind='pie',autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### 8. 문자 1의 df에서 smoker 컬럼에는 레스토랑 방문 고객의 흡연 여부 데이터가 저장되어 있다. 흡연 여부별 고객수를 막대그래프로 나타내시오.

# %%
df['smoker'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### 9. 문제 1의 df에서 time 컬럼에는 레스토랑 고객의 방문 시간대가 저장되어 있다. 방문 시간대별 고객 비율을 원그래프로 나타내시오.

# %%
df['time'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### 10. tips 데이터셋을 불러와 df에 저장한 후, total_bill 컬럼의 값을 amount에 저장하시오. amount는 레스토랑 방문 고객의 결제 금액 데이터다.

# %%
df = sns.load_dataset('tips')
amount = df['total_bill']

# %% [markdown]
# ### 11. amount의 내용과 자료형(type)을 확인하시오.

# %%
display(amount)
display(type(amount))
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64
# pandas.core.series.Series

# %% [markdown]
# ### 12. 고객들의 결제 금액 평균과 중앙값, 표준편차를 출력하시오.

# %%
pd.Series({'평균':amount.mean(), '중앙값': amount.median(), '표준편차': amount.std()})
# Out:
# 평균      19.785943
# 중앙값     17.795000
# 표준편차     8.902412
# dtype: float64

# %% [markdown]
# ### 13. 고객들의 결제 금액 사분위수를 구하시오.

# %%
amount.quantile([0.25,0.5,0.75])
# Out:
# 0.25    13.3475
# 0.50    17.7950
# 0.75    24.1275
# Name: total_bill, dtype: float64

# %% [markdown]
# ### 14. 고객들의 결제 금액을 히스토그램으로 나타내되 막대의 수는 6으로 하시오.

# %%
amount.plot(kind='hist',bins=6)
plt.show()

# %% [markdown]
# ### 15. 문제 14의 히스토그램에 대해 구간별 빈도수를 출력하시오.

# %%
bins = pd.cut(amount,bins=6)
bins.value_counts().sort_index()
# Out:
# total_bill
# (3.022, 11.027]      32
# (11.027, 18.983]    108
# (18.983, 26.94]      59
# (26.94, 34.897]      29
# (34.897, 42.853]      9
# (42.853, 50.81]       7
# Name: count, dtype: int64

# %% [markdown]
# ### 16. 고객들의 결제 금액 분포를 상자그림으로 출력하시오.

# %%
amount.plot(kind='box')
plt.show()

# %% [markdown]
# ### 17. 고객들의 결제 금액 분포를 상자 그림으로 나타내되 방문 시간대(time)별로 상자그림을 나누어 한 화면에 출력하시오.

# %%
df.boxplot(column='total_bill',by='time')
plt.show()

# %% [markdown]
# ### 18. 고객들의 결제 금액 분포에 대한 히스토그램,상자그림,요일별 방문자 수 막대그래프, 원그래프를 한 화면에 출력하시오. 이때 화면을 2x2로 가상 분할하여 각 화면에 그래프를 표시한다.

# %%
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.hist(df['total_bill'], bins=6)

plt.subplot(2,2,2)
plt.boxplot(df['total_bill'])

plt.subplot(2,2,3)
df['day'].value_counts().plot(kind='bar')

plt.subplot(2,2,4)
df['day'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 19. 고객들의 결제 금액 분포에 대한 히스토그램을 작성하되 막대의 색은 초록색으로 하고, 그래프 제목은 '고객의 결제 금액'으로 하시오. 또한 x축 레이블은 '결제 금액', y축 레이블은 '빈도수'로 하시오.

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.hist(df['total_bill'],bins=6,color='green')
plt.title('고객의 결제 금액')
plt.xlabel('결제 금액')
plt.ylabel('빈도수')
plt.show()

# %% [markdown]
# ## 2. 아래 각 문제에 대해 답을 작성하여 Jupyter Notebook 파일로 제출.

# %% [markdown]
# ### (1) 첨부한 “서울시 대기질 자료 제공_2020-2021.csv” 파일을 읽어 데이터프레임(pm_df)에 저장하시오(단, 일시 열은 날짜시간 형식으로 저장).

# %%
import pandas as pd

pm_df = pd.read_csv('서울시 대기질 자료 제공_2020-2021.csv', encoding='cp949', parse_dates=['일시'])

# %% [markdown]
# ### (2) pm_df에서 PM25 컬럼을 제거하시오.

# %%
pm_df = pm_df.drop(columns=['초미세먼지(PM25)'])

pm_df
# Out:
#                         일시   구분  미세먼지(PM10)
# 0      2021-12-31 23:00:00   평균        21.0
# 1      2021-12-31 23:00:00  강남구        21.0
# 2      2021-12-31 23:00:00  강동구        25.0
# 3      2021-12-31 23:00:00  강북구        23.0
# 4      2021-12-31 23:00:00  강서구        28.0
# ...                    ...  ...         ...
# 456137 2020-01-01 00:00:00  용산구        12.0
# 456138 2020-01-01 00:00:00  은평구        18.0
# 456139 2020-01-01 00:00:00  종로구        20.0
# 456140 2020-01-01 00:00:00   중구        22.0
# 456141 2020-01-01 00:00:00  중랑구        22.0
#
# [456142 rows x 3 columns]

# %% [markdown]
# ### (3) pm_df에서 구분의 값이 ‘성북구’를 제외한 모든 행을 제거하시오.

# %%
pm_df = pm_df.loc[pm_df['구분'] == '성북구']

pm_df
# Out:
#                         일시   구분  미세먼지(PM10)
# 17     2021-12-31 23:00:00  성북구        17.0
# 43     2021-12-31 22:00:00  성북구        16.0
# 69     2021-12-31 21:00:00  성북구        13.0
# 95     2021-12-31 20:00:00  성북구        20.0
# 121    2021-12-31 19:00:00  성북구        18.0
# ...                    ...  ...         ...
# 456029 2020-01-01 04:00:00  성북구        27.0
# 456055 2020-01-01 03:00:00  성북구        29.0
# 456081 2020-01-01 02:00:00  성북구        29.0
# 456107 2020-01-01 01:00:00  성북구        24.0
# 456133 2020-01-01 00:00:00  성북구        27.0
#
# [17544 rows x 3 columns]

# %% [markdown]
# ### (4) pm_df에서 결측치의 개수를 보이시오.

# %%
pm_df.isnull().sum()
# Out:
# 일시              0
# 구분              0
# 미세먼지(PM10)    479
# dtype: int64

# %% [markdown]
# ### (5) (3)의 pm_df에서 PM10의 월평균을 구해 데이터프레임 pm10_df에 저장하시오.

# %%
pm_df.loc[:,'월'] = pm_df['일시'].dt.month

pm10_df = pm_df.groupby('월')['미세먼지(PM10)'].mean().reset_index()

pm10_df
# Out:
#      월  미세먼지(PM10)
# 0    1   38.804742
# 1    2   44.612472
# 2    3   56.155373
# 3    4   45.631915
# 4    5   49.993151
# 5    6   36.221053
# 6    7   23.165419
# 7    8   20.925373
# 8    9   16.295341
# 9   10   30.897158
# 10  11   47.008900
# 11  12   40.058943

# %% [markdown]
# ### (6) pm10_df에서 PM10이 가장 높은 달과 낮은 달을 보이시오.

# %%
max_month = pm10_df.loc[pm10_df['미세먼지(PM10)'].idxmax()]
min_month = pm10_df.loc[pm10_df['미세먼지(PM10)'].idxmin()]

max_month,min_month
# Out:
# (월              3.000000
#  미세먼지(PM10)    56.155373
#  Name: 2, dtype: float64,
#  월              9.000000
#  미세먼지(PM10)    16.295341
#  Name: 8, dtype: float64)
